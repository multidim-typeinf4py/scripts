# %%
# %load_ext autoreload
# %autoreload 2

# %pwd
# %cd /home/benji/Documents/Uni/heidelberg/05/masterarbeit/impls/scripts/experiments
# Out:
# /home/benji/Documents/Uni/heidelberg/05/masterarbeit/impls/scripts/experiments

# %%
import pandas as pd

pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199


import pathlib, tqdm

from scripts.common.schemas import TypeCollectionCategory
from scripts.infer.structure import DatasetFolderStructure

tool = "HiType4PyN1"
dataset = DatasetFolderStructure(pathlib.Path(
    "/home/benji/Documents/Uni/heidelberg/05/masterarbeit/datasets/better-types-4-py-dataset"
))
tasks = [TypeCollectionCategory.VARIABLE, TypeCollectionCategory.CALLABLE_PARAMETER, TypeCollectionCategory.CALLABLE_RETURN]

projects = list(dataset.test_set())

# %%
import logging
from importlib import reload

logging.shutdown()
reload(logging)

logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
for handler in logger.handlers:
    logger.removeHandler(handler)
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)

ch.setFormatter(logging.Formatter(f"[{tool} @ %(levelname)s]: %(message)s"))
logger.addHandler(ch)

logger.info("Hello World!")
# Out:
# [HiType4PyN1 @ INFO]: Hello World!

# %%
from pandas.errors import MergeError

from scripts.common.schemas import TypeCollectionSchema
from scripts.common.output import DatasetIO, InferredIO

for project in (pbar := tqdm.tqdm(projects, desc="Ensuring inner join has 1 to 1 correlation with ground truth labels")):
    repository = str(dataset.author_repo(project))
    pbar.set_postfix({"repo": repository})
    
    ground_truth_dataset_io = DatasetIO(
        artifact_root=pathlib.Path(),
        dataset=dataset,
        repository=project,
    )
    
    pred_datasets_io = [InferredIO(
        artifact_root=pathlib.Path(),
        dataset=dataset,
        repository=project,
        tool_name=tool,
        task=task
    ) for task in tasks]
    
    
    ground_truth = ground_truth_dataset_io.read()
    ground_truth_for_task = ground_truth[
        ground_truth[TypeCollectionSchema.category].isin(tasks)
    ].assign(repository=repository)
    
    pred_dataset = pd.concat([
        label_dataset_io.read() 
        for label_dataset_io in label_datasets_io
    ], ignore_index=True).assign(repository=repository)
    
    
    #### Find and remove duplicate ground truth labels
    duplicate_ground_truths = ground_truth_for_task[ground_truth_for_task.duplicated(
        subset=[TypeCollectionSchema.file, TypeCollectionSchema.category, TypeCollectionSchema.qname, TypeCollectionSchema.qname_ssa], 
        keep=False
    )]
    if not duplicate_ground_truths.empty:
        logger.warning(f"{len(duplicate_ground_truths)} duplicate keys found in ground truth: \n{duplicate_ground_truths.to_string()}")
        ground_truth_for_task = ground_truth_for_task.drop_duplicates(
            subset=[TypeCollectionSchema.file, TypeCollectionSchema.category, TypeCollectionSchema.qname, TypeCollectionSchema.qname_ssa], 
            keep=False,
            ignore_index=True,
        )
    
    
    #### Find and remove duplicate inference labels
    duplicate_predictions = pred_dataset[pred_dataset.duplicated(
        subset=[TypeCollectionSchema.file, TypeCollectionSchema.category, TypeCollectionSchema.qname, TypeCollectionSchema.qname_ssa], 
        keep=False,
    )]
    if not duplicate_predictions.empty:
        logger.warning(f"{len(duplicate_predictions)} duplicate keys found in prediction dataset: \n{duplicate_predictions.to_string()}")
        pred_dataset = pred_dataset.drop_duplicates(
            subset=[TypeCollectionSchema.file, TypeCollectionSchema.category, TypeCollectionSchema.qname, TypeCollectionSchema.qname_ssa], 
            keep=False,
            ignore_index=True,
        )

    
    ### Validate one-to-one post-dedup
    pd.merge(
        left=ground_truth_for_task,
        right=pred_dataset,
        on=[TypeCollectionSchema.file, TypeCollectionSchema.category, TypeCollectionSchema.qname, TypeCollectionSchema.qname_ssa],
        validate="1:1"
    )
# Out:
# Ensuring inner join has 1 to 1 correlation with ground truth labels:   0%|                                                                                                              | 0/50 [00:00<?, ?it/s, repo=linw1995__data_extractor][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  linw1995__data_extractor
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  linw1995__data_extractor
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  linw1995__data_extractor
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  linw1995__data_extractor
# Ensuring inner join has 1 to 1 correlation with ground truth labels:   0%|                                                                                                                | 0/50 [00:00<?, ?it/s, repo=albertyw__albertyw.com][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn              repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  albertyw__albertyw.com
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  albertyw__albertyw.com
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  albertyw__albertyw.com
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  albertyw__albertyw.com
# Ensuring inner join has 1 to 1 correlation with ground truth labels:   0%|                                                                                                                      | 0/50 [00:00<?, ?it/s, repo=ocf__slackbridge][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn        repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  ocf__slackbridge
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  ocf__slackbridge
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  ocf__slackbridge
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  ocf__slackbridge
# Ensuring inner join has 1 to 1 correlation with ground truth labels:   6%|██████                                                                                               | 3/50 [00:00<00:01, 25.31it/s, repo=rakitaj__daily-programmer][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                 repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  rakitaj__daily-programmer
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  rakitaj__daily-programmer
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  rakitaj__daily-programmer
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  rakitaj__daily-programmer
# Ensuring inner join has 1 to 1 correlation with ground truth labels:   6%|█████▍                                                                                    | 3/50 [00:00<00:01, 25.31it/s, repo=Gerschtli__teamspeak-update-notifier][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                            repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  Gerschtli__teamspeak-update-notifier
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  Gerschtli__teamspeak-update-notifier
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  Gerschtli__teamspeak-update-notifier
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  Gerschtli__teamspeak-update-notifier
# Ensuring inner join has 1 to 1 correlation with ground truth labels:   6%|██████▏                                                                                                | 3/50 [00:00<00:01, 25.31it/s, repo=basilisp-lang__basilisp][HiType4PyN1 @ WARNING]: 4 duplicate keys found in ground truth:
#                               file            category                  qname              qname_ssa                                      anno               repository
# 8686  src/basilisp/lang/runtime.py     CALLABLE_RETURN       Namespace.module       Namespace.module  src.basilisp.lang.runtime.BasilispModule  basilisp-lang__basilisp
# 8687  src/basilisp/lang/runtime.py  CALLABLE_PARAMETER  Namespace.module.self  Namespace.module.self                                       NaN  basilisp-lang__basilisp
# 8688  src/basilisp/lang/runtime.py     CALLABLE_RETURN       Namespace.module       Namespace.module                                       NaN  basilisp-lang__basilisp
# 8689  src/basilisp/lang/runtime.py  CALLABLE_PARAMETER  Namespace.module.self  Namespace.module.self                                       NaN  basilisp-lang__basilisp
# [HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn               repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  basilisp-lang__basilisp
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  basilisp-lang__basilisp
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  basilisp-lang__basilisp
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  basilisp-lang__basilisp
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  12%|█████████████▏                                                                                                | 6/50 [00:00<00:02, 18.90it/s, repo=seattleflu__id3c][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn        repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  seattleflu__id3c
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  seattleflu__id3c
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  seattleflu__id3c
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  seattleflu__id3c
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  12%|███████████                                                                                 | 6/50 [00:00<00:02, 18.90it/s, repo=ShadowTemplate__beautiful-python-3][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                          repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  ShadowTemplate__beautiful-python-3
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  ShadowTemplate__beautiful-python-3
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  ShadowTemplate__beautiful-python-3
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  ShadowTemplate__beautiful-python-3
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  12%|████████████▌                                                                                            | 6/50 [00:00<00:02, 18.90it/s, repo=eirannejad__calcatime][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn             repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  eirannejad__calcatime
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  eirannejad__calcatime
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  eirannejad__calcatime
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  eirannejad__calcatime
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  18%|█████████████████▊                                                                                 | 9/50 [00:00<00:01, 20.94it/s, repo=road-master__video-archiver][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                   repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  road-master__video-archiver
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  road-master__video-archiver
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  road-master__video-archiver
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  road-master__video-archiver
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  18%|███████████████████▉                                                                                           | 9/50 [00:00<00:01, 20.94it/s, repo=ohjames__babies][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn       repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  ohjames__babies
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  ohjames__babies
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  ohjames__babies
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  ohjames__babies
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  18%|███████████████████▊                                                                                          | 9/50 [00:00<00:01, 20.94it/s, repo=joshtemple__lkml][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn        repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  joshtemple__lkml
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  joshtemple__lkml
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  joshtemple__lkml
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  joshtemple__lkml
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  24%|██████████████████████████▋                                                                                    | 12/50 [00:00<00:01, 22.33it/s, repo=cliffxuan__mew][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn      repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  cliffxuan__mew
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  cliffxuan__mew
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  cliffxuan__mew
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  cliffxuan__mew
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  24%|███████████████████████                                                                         | 12/50 [00:00<00:01, 22.33it/s, repo=yeraydiazdiaz__wait_for_it.py][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                     repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  yeraydiazdiaz__wait_for_it.py
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  yeraydiazdiaz__wait_for_it.py
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  yeraydiazdiaz__wait_for_it.py
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  yeraydiazdiaz__wait_for_it.py
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  24%|█████████████████████████▋                                                                                 | 12/50 [00:00<00:01, 22.33it/s, repo=sonic182__aiosonic][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn          repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  sonic182__aiosonic
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  sonic182__aiosonic
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  sonic182__aiosonic
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  sonic182__aiosonic
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  30%|███████████████████████████████▌                                                                         | 15/50 [00:00<00:01, 23.60it/s, repo=AxelVoitier__lookups][HiType4PyN1 @ WARNING]: 4 duplicate keys found in ground truth:
#                                file            category                 qname             qname_ssa anno            repository
# 924  tests/test_delegated_lookup.py     CALLABLE_RETURN       Provider.lookup       Provider.lookup  NaN  AxelVoitier__lookups
# 925  tests/test_delegated_lookup.py  CALLABLE_PARAMETER  Provider.lookup.self  Provider.lookup.self  NaN  AxelVoitier__lookups
# 926  tests/test_delegated_lookup.py     CALLABLE_RETURN       Provider.lookup       Provider.lookup  NaN  AxelVoitier__lookups
# 927  tests/test_delegated_lookup.py  CALLABLE_PARAMETER  Provider.lookup.self  Provider.lookup.self  NaN  AxelVoitier__lookups
# [HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn            repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  AxelVoitier__lookups
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  AxelVoitier__lookups
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  AxelVoitier__lookups
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  AxelVoitier__lookups
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  30%|████████████████████████████▊                                                                   | 15/50 [00:00<00:01, 23.60it/s, repo=reddit__baseplate.py-upgrader][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                     repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  reddit__baseplate.py-upgrader
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  reddit__baseplate.py-upgrader
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  reddit__baseplate.py-upgrader
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  reddit__baseplate.py-upgrader
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  30%|██████████████████████████████▎                                                                      | 15/50 [00:00<00:01, 23.60it/s, repo=webrecorder__browsertrix][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  webrecorder__browsertrix
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  webrecorder__browsertrix
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  webrecorder__browsertrix
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  webrecorder__browsertrix
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  36%|█████████████████████████████████████▊                                                                   | 18/50 [00:00<00:01, 22.67it/s, repo=TomerFi__aioswitcher][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn            repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  TomerFi__aioswitcher
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  TomerFi__aioswitcher
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  TomerFi__aioswitcher
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  TomerFi__aioswitcher
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  36%|██████████████████████████████████▏                                                            | 18/50 [00:00<00:01, 22.67it/s, repo=amplify-education__python-hcl2][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                      repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  amplify-education__python-hcl2
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  amplify-education__python-hcl2
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  amplify-education__python-hcl2
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  amplify-education__python-hcl2
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  36%|████████████████████████████████████▋                                                                 | 18/50 [00:00<00:01, 22.67it/s, repo=flopp__unicode-explorer][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn               repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  flopp__unicode-explorer
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  flopp__unicode-explorer
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  flopp__unicode-explorer
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  flopp__unicode-explorer
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  42%|████████████████████████████████████▌                                                  | 21/50 [00:00<00:01, 23.36it/s, repo=lucaswerkmeister__tool-quickcategories][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                              repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  lucaswerkmeister__tool-quickcategories
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  lucaswerkmeister__tool-quickcategories
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  lucaswerkmeister__tool-quickcategories
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  lucaswerkmeister__tool-quickcategories
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  42%|████████████████████████████████████████████▉                                                              | 21/50 [00:00<00:01, 23.36it/s, repo=srittau__FakeSMTPd][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn          repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  srittau__FakeSMTPd
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  srittau__FakeSMTPd
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  srittau__FakeSMTPd
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  srittau__FakeSMTPd
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  42%|█████████████████████████████████████████▌                                                         | 21/50 [00:01<00:01, 23.36it/s, repo=ActivityWatch__aw-research][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                  repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  ActivityWatch__aw-research
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  ActivityWatch__aw-research
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  ActivityWatch__aw-research
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  ActivityWatch__aw-research
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  48%|████████████████████████████████████████████████▍                                                    | 24/50 [00:01<00:01, 23.65it/s, repo=kitsuyui__bamboo-crawler][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  kitsuyui__bamboo-crawler
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  kitsuyui__bamboo-crawler
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  kitsuyui__bamboo-crawler
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  kitsuyui__bamboo-crawler
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  48%|████████████████████████████████████████████▋                                                | 24/50 [00:01<00:01, 23.65it/s, repo=typeddjango__pytest-mypy-plugins][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                        repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  typeddjango__pytest-mypy-plugins
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  typeddjango__pytest-mypy-plugins
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  typeddjango__pytest-mypy-plugins
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  typeddjango__pytest-mypy-plugins
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  48%|█████████████████████████████████████████████████▉                                                      | 24/50 [00:01<00:01, 23.65it/s, repo=ClearcodeHQ__mirakuru][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn             repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  ClearcodeHQ__mirakuru
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  ClearcodeHQ__mirakuru
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  ClearcodeHQ__mirakuru
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  ClearcodeHQ__mirakuru
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  54%|███████████████████████████████████████████████████▎                                           | 27/50 [00:01<00:00, 24.43it/s, repo=silasary__discord_connotations][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                      repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  silasary__discord_connotations
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  silasary__discord_connotations
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  silasary__discord_connotations
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  silasary__discord_connotations
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  54%|████████████████████████████████████████████████████████▏                                               | 27/50 [00:01<00:00, 24.43it/s, repo=kornicameister__axion][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn             repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  kornicameister__axion
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  kornicameister__axion
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  kornicameister__axion
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  kornicameister__axion
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  54%|███████████████████████████████████████████████████████▌                                               | 27/50 [00:01<00:00, 24.43it/s, repo=ammarnajjar__pautomate][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn              repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  ammarnajjar__pautomate
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  ammarnajjar__pautomate
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  ammarnajjar__pautomate
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  ammarnajjar__pautomate
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  60%|█████████████████████████████████████████████████████████████▏                                        | 30/50 [00:01<00:00, 24.78it/s, repo=brettkromkamp__topic-db][HiType4PyN1 @ WARNING]: 48 duplicate keys found in ground truth:
#                                    file            category                             qname                         qname_ssa                                              anno               repository
# 102        src/topicdb/models/entity.py     CALLABLE_RETURN                Entity.instance_of                Entity.instance_of                                      builtins.str  brettkromkamp__topic-db
# 103        src/topicdb/models/entity.py  CALLABLE_PARAMETER           Entity.instance_of.self           Entity.instance_of.self                                               NaN  brettkromkamp__topic-db
# 104        src/topicdb/models/entity.py     CALLABLE_RETURN                Entity.instance_of                Entity.instance_of                                              None  brettkromkamp__topic-db
# 105        src/topicdb/models/entity.py  CALLABLE_PARAMETER           Entity.instance_of.self           Entity.instance_of.self                                               NaN  brettkromkamp__topic-db
# 151     src/topicdb/models/attribute.py     CALLABLE_RETURN       Attribute.entity_identifier       Attribute.entity_identifier                                      builtins.str  brettkromkamp__topic-db
# 152     src/topicdb/models/attribute.py  CALLABLE_PARAMETER  Attribute.entity_identifier.self  Attribute.entity_identifier.self                                               NaN  brettkromkamp__topic-db
# 153     src/topicdb/models/attribute.py     CALLABLE_RETURN       Attribute.entity_identifier       Attribute.entity_identifier                                              None  brettkromkamp__topic-db
# 154     src/topicdb/models/attribute.py  CALLABLE_PARAMETER  Attribute.entity_identifier.self  Attribute.entity_identifier.self                                               NaN  brettkromkamp__topic-db
# 158     src/topicdb/models/attribute.py     CALLABLE_RETURN                   Attribute.scope                   Attribute.scope                                      builtins.str  brettkromkamp__topic-db
# 159     src/topicdb/models/attribute.py  CALLABLE_PARAMETER              Attribute.scope.self              Attribute.scope.self                                               NaN  brettkromkamp__topic-db
# 160     src/topicdb/models/attribute.py     CALLABLE_RETURN                   Attribute.scope                   Attribute.scope                                              None  brettkromkamp__topic-db
# 161     src/topicdb/models/attribute.py  CALLABLE_PARAMETER              Attribute.scope.self              Attribute.scope.self                                               NaN  brettkromkamp__topic-db
# 274    src/topicdb/models/occurrence.py     CALLABLE_RETURN                  Occurrence.scope                  Occurrence.scope                                      builtins.str  brettkromkamp__topic-db
# 275    src/topicdb/models/occurrence.py  CALLABLE_PARAMETER             Occurrence.scope.self             Occurrence.scope.self                                               NaN  brettkromkamp__topic-db
# 276    src/topicdb/models/occurrence.py     CALLABLE_RETURN                  Occurrence.scope                  Occurrence.scope                                              None  brettkromkamp__topic-db
# 277    src/topicdb/models/occurrence.py  CALLABLE_PARAMETER             Occurrence.scope.self             Occurrence.scope.self                                               NaN  brettkromkamp__topic-db
# 279    src/topicdb/models/occurrence.py     CALLABLE_RETURN       Occurrence.topic_identifier       Occurrence.topic_identifier                                      builtins.str  brettkromkamp__topic-db
# 280    src/topicdb/models/occurrence.py  CALLABLE_PARAMETER  Occurrence.topic_identifier.self  Occurrence.topic_identifier.self                                               NaN  brettkromkamp__topic-db
# 281    src/topicdb/models/occurrence.py     CALLABLE_RETURN       Occurrence.topic_identifier       Occurrence.topic_identifier                                              None  brettkromkamp__topic-db
# 282    src/topicdb/models/occurrence.py  CALLABLE_PARAMETER  Occurrence.topic_identifier.self  Occurrence.topic_identifier.self                                               NaN  brettkromkamp__topic-db
# 284    src/topicdb/models/occurrence.py     CALLABLE_RETURN          Occurrence.resource_data          Occurrence.resource_data  typing.Union[None, builtins.bytes, builtins.str]  brettkromkamp__topic-db
# 285    src/topicdb/models/occurrence.py  CALLABLE_PARAMETER     Occurrence.resource_data.self     Occurrence.resource_data.self                                               NaN  brettkromkamp__topic-db
# 286    src/topicdb/models/occurrence.py     CALLABLE_RETURN          Occurrence.resource_data          Occurrence.resource_data                                              None  brettkromkamp__topic-db
# 287    src/topicdb/models/occurrence.py  CALLABLE_PARAMETER     Occurrence.resource_data.self     Occurrence.resource_data.self                                               NaN  brettkromkamp__topic-db
# 1032  src/topicdb/models/association.py     CALLABLE_RETURN                 Association.scope                 Association.scope                                      builtins.str  brettkromkamp__topic-db
# 1033  src/topicdb/models/association.py  CALLABLE_PARAMETER            Association.scope.self            Association.scope.self                                               NaN  brettkromkamp__topic-db
# 1034  src/topicdb/models/association.py     CALLABLE_RETURN                 Association.scope                 Association.scope                                              None  brettkromkamp__topic-db
# 1035  src/topicdb/models/association.py  CALLABLE_PARAMETER            Association.scope.self            Association.scope.self                                               NaN  brettkromkamp__topic-db
# 1050       src/topicdb/models/member.py     CALLABLE_RETURN              Member.src_topic_ref              Member.src_topic_ref                                      builtins.str  brettkromkamp__topic-db
# 1051       src/topicdb/models/member.py  CALLABLE_PARAMETER         Member.src_topic_ref.self         Member.src_topic_ref.self                                               NaN  brettkromkamp__topic-db
# 1052       src/topicdb/models/member.py     CALLABLE_RETURN              Member.src_topic_ref              Member.src_topic_ref                                              None  brettkromkamp__topic-db
# 1053       src/topicdb/models/member.py  CALLABLE_PARAMETER         Member.src_topic_ref.self         Member.src_topic_ref.self                                               NaN  brettkromkamp__topic-db
# 1055       src/topicdb/models/member.py     CALLABLE_RETURN              Member.src_role_spec              Member.src_role_spec                                      builtins.str  brettkromkamp__topic-db
# 1056       src/topicdb/models/member.py  CALLABLE_PARAMETER         Member.src_role_spec.self         Member.src_role_spec.self                                               NaN  brettkromkamp__topic-db
# 1057       src/topicdb/models/member.py     CALLABLE_RETURN              Member.src_role_spec              Member.src_role_spec                                              None  brettkromkamp__topic-db
# 1058       src/topicdb/models/member.py  CALLABLE_PARAMETER         Member.src_role_spec.self         Member.src_role_spec.self                                               NaN  brettkromkamp__topic-db
# 1060       src/topicdb/models/member.py     CALLABLE_RETURN             Member.dest_topic_ref             Member.dest_topic_ref                                      builtins.str  brettkromkamp__topic-db
# 1061       src/topicdb/models/member.py  CALLABLE_PARAMETER        Member.dest_topic_ref.self        Member.dest_topic_ref.self                                               NaN  brettkromkamp__topic-db
# 1062       src/topicdb/models/member.py     CALLABLE_RETURN             Member.dest_topic_ref             Member.dest_topic_ref                                              None  brettkromkamp__topic-db
# 1063       src/topicdb/models/member.py  CALLABLE_PARAMETER        Member.dest_topic_ref.self        Member.dest_topic_ref.self                                               NaN  brettkromkamp__topic-db
# 1065       src/topicdb/models/member.py     CALLABLE_RETURN             Member.dest_role_spec             Member.dest_role_spec                                      builtins.str  brettkromkamp__topic-db
# 1066       src/topicdb/models/member.py  CALLABLE_PARAMETER        Member.dest_role_spec.self        Member.dest_role_spec.self                                               NaN  brettkromkamp__topic-db
# 1067       src/topicdb/models/member.py     CALLABLE_RETURN             Member.dest_role_spec             Member.dest_role_spec                                              None  brettkromkamp__topic-db
# 1068       src/topicdb/models/member.py  CALLABLE_PARAMETER        Member.dest_role_spec.self        Member.dest_role_spec.self                                               NaN  brettkromkamp__topic-db
# 1089     src/topicdb/models/basename.py     CALLABLE_RETURN                    BaseName.scope                    BaseName.scope                                      builtins.str  brettkromkamp__topic-db
# 1090     src/topicdb/models/basename.py  CALLABLE_PARAMETER               BaseName.scope.self               BaseName.scope.self                                               NaN  brettkromkamp__topic-db
# 1091     src/topicdb/models/basename.py     CALLABLE_RETURN                    BaseName.scope                    BaseName.scope                                              None  brettkromkamp__topic-db
# 1092     src/topicdb/models/basename.py  CALLABLE_PARAMETER               BaseName.scope.self               BaseName.scope.self                                               NaN  brettkromkamp__topic-db
# [HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn               repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  brettkromkamp__topic-db
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  brettkromkamp__topic-db
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  brettkromkamp__topic-db
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  brettkromkamp__topic-db
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  60%|████████████████████████████████████████████████████████████                                        | 30/50 [00:01<00:00, 24.78it/s, repo=antonagestam__collectfast][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                 repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  antonagestam__collectfast
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  antonagestam__collectfast
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  antonagestam__collectfast
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  antonagestam__collectfast
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  60%|███████████████████████████████████████████████████████████████                                          | 30/50 [00:01<00:00, 24.78it/s, repo=jfly__jfly.github.io][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn            repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  jfly__jfly.github.io
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  jfly__jfly.github.io
# ...
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  paulcwatts__drf-json-schema
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  paulcwatts__drf-json-schema
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  78%|█████████████████████████████████████████████████████████████████████████████████████▊                        | 39/50 [00:01<00:00, 24.15it/s, repo=nubark__instark][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn       repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  nubark__instark
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  nubark__instark
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  nubark__instark
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  nubark__instark
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  78%|█████████████████████████████████████████████████████████████████████▍                   | 39/50 [00:01<00:00, 24.15it/s, repo=marcosschroh__dataclasses-avroschema][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                            repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  marcosschroh__dataclasses-avroschema
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  marcosschroh__dataclasses-avroschema
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  marcosschroh__dataclasses-avroschema
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  marcosschroh__dataclasses-avroschema
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  84%|██████████████████████████████████████████████████████████████████████████████████████████▋                 | 42/50 [00:01<00:00, 22.82it/s, repo=knowark__estimark][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn         repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  knowark__estimark
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  knowark__estimark
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  knowark__estimark
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  knowark__estimark
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  84%|█████████████████████████████████████████████████████████████████████████████████████████████▏                 | 42/50 [00:01<00:00, 22.82it/s, repo=JakobGM__quelf][HiType4PyN1 @ WARNING]: 4 duplicate keys found in ground truth:
#                file            category               qname           qname_ssa                     anno      repository
# 240  quelf/toggl.py     CALLABLE_RETURN       Toggl.details       Toggl.details  quelf.toggl.DetailsDict  JakobGM__quelf
# 241  quelf/toggl.py  CALLABLE_PARAMETER  Toggl.details.self  Toggl.details.self                      NaN  JakobGM__quelf
# 242  quelf/toggl.py     CALLABLE_RETURN       Toggl.details       Toggl.details                      NaN  JakobGM__quelf
# 243  quelf/toggl.py  CALLABLE_PARAMETER  Toggl.details.self  Toggl.details.self                      NaN  JakobGM__quelf
# [HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn      repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  JakobGM__quelf
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  JakobGM__quelf
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  JakobGM__quelf
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  JakobGM__quelf
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  84%|██████████████████████████████████████████████████████████████████████████████████████▌                | 42/50 [00:01<00:00, 22.82it/s, repo=boompig__book-classics][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn              repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  boompig__book-classics
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  boompig__book-classics
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  boompig__book-classics
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  boompig__book-classics
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  90%|████████████████████████████████████████████████████████████████████████████████████████████████▎          | 45/50 [00:01<00:00, 23.27it/s, repo=nabla-c0d3__sslyze][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn          repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  nabla-c0d3__sslyze
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  nabla-c0d3__sslyze
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  nabla-c0d3__sslyze
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  nabla-c0d3__sslyze
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  90%|██████████████████████████████████████████████████████████████████████████████████████████████▌          | 45/50 [00:01<00:00, 23.27it/s, repo=lebrice__blurred-GAN][HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn            repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  lebrice__blurred-GAN
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  lebrice__blurred-GAN
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  lebrice__blurred-GAN
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  lebrice__blurred-GAN
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  90%|██████████████████████████████████████████████████████████████████████████████████████████████▌          | 45/50 [00:02<00:00, 23.27it/s, repo=futursolo__magichttp][HiType4PyN1 @ WARNING]: 4 duplicate keys found in ground truth:
#                       file            category                                  qname                              qname_ssa          anno            repository
# 1091  magichttp/readers.py     CALLABLE_RETURN       BaseHttpStreamReader.max_buf_len       BaseHttpStreamReader.max_buf_len  builtins.int  futursolo__magichttp
# 1092  magichttp/readers.py  CALLABLE_PARAMETER  BaseHttpStreamReader.max_buf_len.self  BaseHttpStreamReader.max_buf_len.self           NaN  futursolo__magichttp
# 1093  magichttp/readers.py     CALLABLE_RETURN       BaseHttpStreamReader.max_buf_len       BaseHttpStreamReader.max_buf_len          None  futursolo__magichttp
# 1094  magichttp/readers.py  CALLABLE_PARAMETER  BaseHttpStreamReader.max_buf_len.self  BaseHttpStreamReader.max_buf_len.self           NaN  futursolo__magichttp
# [HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn            repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  futursolo__magichttp
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  futursolo__magichttp
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  futursolo__magichttp
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  futursolo__magichttp
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  96%|████████████████████████████████████████████████████████████████████████████████████████████▏   | 48/50 [00:02<00:00, 22.45it/s, repo=everyclass__everyclass-server][HiType4PyN1 @ WARNING]: 9 duplicate keys found in ground truth:
#                                                   file            category                         qname                     qname_ssa                               anno                     repository
# 829  everyclass/server/calendar/repo/calendar_token.py     CALLABLE_RETURN           find_calendar_token           find_calendar_token  typing.Union[builtins.dict, None]  everyclass__everyclass-server
# 830  everyclass/server/calendar/repo/calendar_token.py  CALLABLE_PARAMETER     find_calendar_token.token     find_calendar_token.token                       builtins.str  everyclass__everyclass-server
# 831  everyclass/server/calendar/repo/calendar_token.py     CALLABLE_RETURN           find_calendar_token           find_calendar_token  typing.Union[builtins.dict, None]  everyclass__everyclass-server
# 832  everyclass/server/calendar/repo/calendar_token.py  CALLABLE_PARAMETER       find_calendar_token.sid       find_calendar_token.sid                       builtins.str  everyclass__everyclass-server
# 833  everyclass/server/calendar/repo/calendar_token.py  CALLABLE_PARAMETER  find_calendar_token.semester  find_calendar_token.semester                       builtins.str  everyclass__everyclass-server
# 834  everyclass/server/calendar/repo/calendar_token.py     CALLABLE_RETURN           find_calendar_token           find_calendar_token                                NaN  everyclass__everyclass-server
# 836  everyclass/server/calendar/repo/calendar_token.py  CALLABLE_PARAMETER       find_calendar_token.sid       find_calendar_token.sid                                NaN  everyclass__everyclass-server
# 837  everyclass/server/calendar/repo/calendar_token.py  CALLABLE_PARAMETER  find_calendar_token.semester  find_calendar_token.semester                                NaN  everyclass__everyclass-server
# 838  everyclass/server/calendar/repo/calendar_token.py  CALLABLE_PARAMETER     find_calendar_token.token     find_calendar_token.token                                NaN  everyclass__everyclass-server
# [HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn                     repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  everyclass__everyclass-server
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  everyclass__everyclass-server
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  everyclass__everyclass-server
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  everyclass__everyclass-server
# Ensuring inner join has 1 to 1 correlation with ground truth labels:  96%|███████████████████████████████████████████████████████████████████████████████████████████████████▊    | 48/50 [00:02<00:00, 22.45it/s, repo=flopp__GpxTrackPoster][HiType4PyN1 @ WARNING]: 4 duplicate keys found in ground truth:
#                         file            category                     qname                 qname_ssa            anno             repository
# 445  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.float  flopp__GpxTrackPoster
# 446  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self             NaN  flopp__GpxTrackPoster
# 447  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters            None  flopp__GpxTrackPoster
# 448  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self             NaN  flopp__GpxTrackPoster
# [HiType4PyN1 @ WARNING]: 4 duplicate keys found in prediction dataset:
#                         file            category                     qname                 qname_ssa          anno       method  topn             repository
# 773  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  flopp__GpxTrackPoster
# 774  gpxtrackposter/track.py  CALLABLE_PARAMETER  Track.length_meters.self  Track.length_meters.self           NaN  HiType4PyN1     1  flopp__GpxTrackPoster
# 904  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters  builtins.int  HiType4PyN1     1  flopp__GpxTrackPoster
# 905  gpxtrackposter/track.py     CALLABLE_RETURN       Track.length_meters       Track.length_meters           NaN  HiType4PyN1     1  flopp__GpxTrackPoster
# Ensuring inner join has 1 to 1 correlation with ground truth labels: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:02<00:00, 23.04it/s, repo=flopp__GpxTrackPoster]

# %%
all_ground_truths_vs_predictions = pl.concat(queries_for_inner)
logger.info(f"Unprocessed sample size: {all_ground_truths_vs_predictions.shape}")
        
# Just about every publication does this: Ignore typing.Any, Any and None as it is not helpful to predict these
without_useless_annotations = all_ground_truths_vs_predictions.filter(~pl.col(ExtendedInferredSchema.anno).is_in(["typing.Any", "Any", "None"]))
logger.info(f"After removing typing.Any, Any and None from ground truth: {without_useless_annotations.shape}")
    
# Remove everything where there is no label in the ground truth dataset
no_ground_truth_label = without_useless_annotations.drop_nulls(subset=ExtendedInferredSchema.anno)
logger.info(f"After removing NULLs in ground truth annotation column: {no_ground_truth_label.shape}")

# Remove all whitespace
no_ground_truth_label = no_ground_truth_label.with_columns([
    pl.col(ExtendedInferredSchema.anno).str.replace_all(" ", ""),
    pl.col(ExtendedInferredSchema.parametric_anno).str.replace_all(" ", ""),
    pl.col("anno_predict").str.replace_all(" ", ""),
    pl.col("parametric_anno_predict").str.replace_all(" ", ""),
])
#print(no_ground_truth_label.sample(n=30))
            
# Remove trivial functions from the dataset: 'init' 'str', 'unicode', 'repr', 'len', 'doc', 'sizeof'
# adapted taken from type4py's preprocessing

# Retain everything that is not a callable or (if it is!) does not end with one of these methods
without_trivial_functions = no_ground_truth_label.filter(
    ~((pl.col(ExtendedTypeCollectionSchema.category) == str(TypeCollectionCategory.CALLABLE_RETURN)) &
    (
            pl.col(ExtendedTypeCollectionSchema.qname).str.ends_with(".__init__") |
            pl.col(ExtendedTypeCollectionSchema.qname).str.ends_with(".__str__") |
            pl.col(ExtendedTypeCollectionSchema.qname).str.ends_with(".__unicode__") |
            pl.col(ExtendedTypeCollectionSchema.qname).str.ends_with(".__repr__") |
            pl.col(ExtendedTypeCollectionSchema.qname).str.ends_with(".__len__") |
            pl.col(ExtendedTypeCollectionSchema.qname).str.ends_with(".__doc__") |
            pl.col(ExtendedTypeCollectionSchema.qname).str.ends_with(".__sizeof__")
    ))
)
logger.info(f"After removing trivially inferrable functions: {without_trivial_functions.shape}")


# Remove parameters for which it makes no sense to make predictions for (cls, self)
without_trivial_parameters = without_trivial_functions.filter(
    ~((pl.col(ExtendedTypeCollectionSchema.category) == str(TypeCollectionCategory.CALLABLE_PARAMETER)) &
    (
            pl.col(ExtendedTypeCollectionSchema.qname).str.ends_with(".cls") |
            pl.col(ExtendedTypeCollectionSchema.qname).str.ends_with(".self") |
            pl.col(ExtendedTypeCollectionSchema.qname).str.ends_with(".args") |
            pl.col(ExtendedTypeCollectionSchema.qname).str.ends_with(".kwargs")
    ))
)
logger.info(f"After removing trivially inferrable parameters: {without_trivial_parameters.shape}")


# Remove variables that are not intended to be seen anyway
without_useless_variables = without_trivial_parameters.filter(
    ~((pl.col(ExtendedTypeCollectionSchema.category) == str(TypeCollectionCategory.VARIABLE)) &
    (
        pl.col(ExtendedTypeCollectionSchema.qname).str.ends_with("._")
    ))
)
logger.info(f"After removing useless variables: {without_useless_variables.shape}")


filtered_ground_truths_vs_predictions = without_useless_variables
#logger.info(filtered_ground_truths_vs_predictions.select(
#    pl.col("repository"),
#    pl.col(ExtendedInferredSchema.file),
#    pl.col(ExtendedInferredSchema.category),
#    pl.col(ExtendedInferredSchema.qname_ssa),
#    pl.col(ExtendedInferredSchema.anno),
#    pl.col("anno_predict"),
#).sample(n=20))

# Remove TT5 artifacts
filtered_ground_truths_vs_predictions = filtered_ground_truths_vs_predictions.filter(
    pl.col("anno_predict") != "..."
)


logger.info(filtered_ground_truths_vs_predictions.select(
    pl.col("repository"),
    pl.col(ExtendedInferredSchema.file),
    pl.col(ExtendedInferredSchema.category),
    pl.col(ExtendedInferredSchema.qname_ssa),
    pl.col(ExtendedInferredSchema.anno),
    pl.col("anno_predict"),
).sample(n=20))

# Dequalify all annotations as TypeT5 did
def dequalify(annotation: str | None) -> str | None:
    import libcst
    from libcst import matchers as m
    class Dequalifier(libcst.CSTTransformer):
        def __init__(self) -> None:
            super().__init__()

        def leave_Attribute(
            self, original_node: libcst.Attribute, updated_node: libcst.Attribute
        ) -> libcst.Name:
            return updated_node.attr
        
        def leave_Subscript(
            self,
            original_node: libcst.Subscript,
            updated_node: libcst.Subscript,
        ) -> libcst.Subscript:
            import typing
            from scripts.common import _stringify
            
            if not m.matches(updated_node, m.Subscript(value=m.Name("Union") | m.Attribute(m.Name(), m.Name("Union")))):
                return updated_node

            # Resort union entries
            subscript_elems_as_str = [_stringify(se.slice.value) for se in updated_node.slice]
            as_sorted = sorted(subscript_elems_as_str)

            sorted_union = libcst.parse_expression(
                f"Union[{','.join(as_sorted)}]"
            )

            return typing.cast(libcst.Subscript, sorted_union)
    
    if annotation is None:
        return None
    return libcst.parse_module(annotation).visit(Dequalifier()).code

filtered_ground_truths_vs_predictions = filtered_ground_truths_vs_predictions.with_columns([
    pl.col(ExtendedInferredSchema.anno).apply(lambda a: dequalify(a)).alias("rewritten_anno"),
    pl.col(ExtendedInferredSchema.parametric_anno).apply(lambda a: dequalify(a)).alias("rewritten_parametric_anno"),
    pl.col("anno_predict").apply(lambda a: dequalify(a)).alias("rewritten_anno_predict"),
    pl.col("parametric_anno_predict").apply(lambda a: dequalify(a)).alias("rewritten_parametric_anno_predict"),
])
